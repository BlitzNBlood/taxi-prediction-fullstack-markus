# %%
import pandas as pd
pd.set_option("display.max_columns", None)
df = pd.read_csv("taxi_trip_pricing.csv")
df.head(100)
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35     Morning     Weekday              3.0
# 1              47.59   Afternoon     Weekday              1.0
# 2              36.87     Evening     Weekend              1.0
# 3              30.33     Evening     Weekday              4.0
# 4                NaN     Evening     Weekday              3.0
# ..               ...         ...         ...              ...
# 95               NaN     Morning     Weekend              1.0
# 96             26.61     Morning     Weekday              4.0
# 97             21.95     Morning     Weekday              3.0
# 98              2.25     Evening     Weekend              3.0
# 99              6.29   Afternoon     Weekday              3.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                 Low   Clear       3.56         0.80             0.32
# 1                High   Clear        NaN         0.62             0.43
# 2                High   Clear       2.70         1.21             0.15
# 3                 Low     NaN       3.48         0.51             0.15
# 4                High   Clear       2.93         0.63             0.32
# ..                ...     ...        ...          ...              ...
# 95             Medium   Clear       3.43         0.91             0.50
# 96                Low    Rain       3.07         0.68             0.18
# 97             Medium   Clear       4.05         0.88             0.10
# 98                Low   Clear       3.99         1.88             0.50
# 99                NaN   Clear       4.15         1.37             0.21
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 1                   40.57         NaN
# 2                   37.27     52.9032
# 3                  116.81     36.4698
# 4                   22.64     15.6180
# ..                    ...         ...
# 95                  67.43     60.0770
# 96                  65.91     33.0286
# 97                  44.99     27.8650
# 98                    NaN     40.6500
# 99                  80.37     29.6450
#
# [100 rows x 11 columns]

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
df = pd.read_csv("taxi_trip_pricing.csv")
for columns in df:
    if (columns == 'Base_Fare' or columns == 'Per_Km_Rate' or columns == 'Per_Minute_Rate'):
        loop_count = 0
        for rows in df[columns]:
            if (pd.isnull(df[columns].iloc[loop_count]) == True):
                df.loc[loop_count, columns] = 0.0
            loop_count = loop_count + 1
    else:
        df = df[df[columns].isnull() == False]
        df = df.reset_index(drop=True)
df.head(20)
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0          19.350000     Morning     Weekday              3.0
# 1          36.870000     Evening     Weekend              1.0
# 2           8.640000   Afternoon     Weekend              2.0
# 3           3.850000   Afternoon     Weekday              4.0
# 4          41.790000       Night     Weekend              3.0
# 5           9.910000     Evening     Weekday              2.0
# 6           9.990000       Night     Weekday              4.0
# 7          15.910000     Morning     Weekday              4.0
# 8          26.710000   Afternoon     Weekend              4.0
# 9          30.980000   Afternoon     Weekend              1.0
# 10        105.943550       Night     Weekend              2.0
# 11         18.950000       Night     Weekday              1.0
# 12         39.470000   Afternoon     Weekday              1.0
# 13        138.098328     Evening     Weekend              4.0
# 14          3.280000     Evening     Weekday              2.0
# 15         30.770000     Morning     Weekday              1.0
# 16          9.360000   Afternoon     Weekday              1.0
# 17         48.320000     Morning     Weekday              2.0
# 18         40.610000   Afternoon     Weekday              1.0
# 19          5.790000     Evening     Weekday              4.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                 Low   Clear       3.56         0.80             0.32
# 1                High   Clear       2.70         1.21             0.15
# 2              Medium   Clear       2.55         1.71             0.48
# 3                High    Rain       3.51         1.66             0.00
# 4                High   Clear       4.60         1.77             0.11
# 5                High   Clear       2.32         1.26             0.34
# 6                High   Clear       4.33         0.85             0.43
# 7                 Low   Clear       4.42         1.77             0.21
# 8                 Low    Rain       4.30         1.59             0.20
# 9                 Low    Rain       4.50         0.84             0.25
# 10                Low    Rain       3.94         1.69             0.32
# 11                Low   Clear       3.38         0.78             0.39
# 12                Low   Clear       0.00         0.00             0.35
# 13             Medium    Rain       2.24         1.75             0.32
# 14             Medium   Clear       2.88         1.76             0.20
# 15                Low   Clear       3.64         1.33             0.13
# 16             Medium   Clear       2.40         1.85             0.15
# 17                Low   Clear       2.49         0.61             0.44
# 18                Low   Clear       2.31         0.88             0.38
# 19                Low   Clear       4.63         1.83             0.24
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82   36.262400
# 1                   37.27   52.903200
# 2                   89.33   60.202800
# 3                    5.05   11.264500
# 4                   86.95   88.132800
# 5                   41.72   28.991400
# 6                   34.00   27.441500
# 7                  114.93   56.716000
# 8                  111.18   69.004900
# 9                   57.02   44.778200
# 10                  23.03  201.869509
# 11                  54.04   39.236600
# 12                   7.59   83.696500
# 13                  94.86  280.877302
# 14                  78.04   24.260800
# 15                 109.60   58.812100
# 16                   7.07   20.776500
# 17                  67.25   61.555200
# 18                  42.25   54.101800
# 19                 107.07   40.922500

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
df = pd.read_csv("taxi_trip_pricing.csv")
df = df[df['Trip_Price'].isnull() == True]
df = df.reset_index(drop=True)
df.head(100)
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0              47.59   Afternoon     Weekday              1.0
# 1              30.45     Morning     Weekday              3.0
# 2              48.53       Night     Weekday              3.0
# 3               4.19     Morning     Weekday              1.0
# 4              38.78     Morning     Weekday              3.0
# 5               4.77     Morning     Weekend              2.0
# 6              16.58     Evening         NaN              2.0
# 7              10.14   Afternoon     Weekday              4.0
# 8              19.95     Morning     Weekday              3.0
# 9              46.90     Evening     Weekday              1.0
# 10             33.51   Afternoon     Weekend              3.0
# 11             32.95     Morning     Weekday              1.0
# 12             35.90         NaN     Weekend              2.0
# 13             44.71       Night     Weekday              1.0
# 14             49.51     Evening     Weekday              3.0
# 15              7.86   Afternoon         NaN              3.0
# 16             26.40   Afternoon     Weekday              4.0
# 17             43.99     Morning     Weekday              3.0
# 18             26.06   Afternoon     Weekend              4.0
# 19             25.57     Morning     Weekday              3.0
# 20              2.76   Afternoon     Weekday              3.0
# 21             21.56   Afternoon     Weekday              1.0
# 22             22.02     Morning     Weekday              1.0
# 23              1.53     Evening     Weekday              1.0
# 24             22.63     Morning     Weekday              2.0
# 25              5.09   Afternoon     Weekday              4.0
# 26             13.65   Afternoon     Weekday              2.0
# 27             31.29     Morning     Weekday              3.0
# 28             44.87   Afternoon         NaN              4.0
# 29             26.07   Afternoon     Weekday              1.0
# 30              1.98   Afternoon     Weekday              3.0
# 31             17.05   Afternoon     Weekday              4.0
# 32             32.65   Afternoon     Weekday              1.0
# 33             10.14     Morning     Weekend              4.0
# 34              6.49     Morning     Weekday              3.0
# 35              9.02   Afternoon     Weekday              3.0
# 36             22.52   Afternoon     Weekend              2.0
# 37             17.41     Morning     Weekday              NaN
# 38              8.43   Afternoon     Weekday              4.0
# 39             23.64     Morning     Weekend              1.0
# 40             29.45       Night     Weekend              NaN
# 41             14.27     Morning     Weekend              1.0
# 42             12.92       Night     Weekend              2.0
# 43             41.68     Evening         NaN              1.0
# 44             29.92   Afternoon     Weekday              1.0
# 45             43.55   Afternoon     Weekday              2.0
# 46             45.80     Evening     Weekday              2.0
# 47             30.16     Morning     Weekend              4.0
# 48             35.04     Morning     Weekend              4.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                High   Clear        NaN         0.62             0.43
# 1                High   Clear       2.77         1.78             0.34
# 2                 Low   Clear       4.78          NaN             0.50
# 3                 Low   Clear       4.07         1.89             0.19
# 4              Medium   Clear       3.08         1.62             0.15
# 5                High   Clear        NaN         0.96             0.18
# 6                 Low   Clear       4.46         1.23             0.16
# 7                 Low    Rain       4.50         1.62             0.38
# 8                 Low     NaN       2.50         0.88             0.49
# 9                High   Clear       4.14         1.33             0.13
# 10                Low   Clear       2.31         1.32             0.40
# 11             Medium   Clear       3.36         1.56             0.19
# 12               High   Clear       4.03         1.79             0.13
# 13                Low    Rain       2.50         1.94             0.47
# 14             Medium    Snow       4.81         0.74             0.14
# 15             Medium    Rain       4.82         0.75             0.26
# 16                Low   Clear       2.52          NaN             0.39
# 17             Medium   Clear       4.62         1.69             0.36
# 18             Medium   Clear       2.08         1.14             0.23
# 19               High    Rain       3.13         0.93             0.11
# 20                Low   Clear       4.73         1.81             0.30
# 21               High   Clear        NaN         1.51             0.32
# 22               High   Clear        NaN         0.51             0.30
# 23                Low   Clear       4.33         1.70             0.42
# 24             Medium   Clear       4.33          NaN             0.44
# 25                Low     NaN       4.48         0.53             0.21
# 26                Low   Clear       3.07         1.61             0.29
# 27             Medium    Rain       4.41          NaN             0.21
# 28                Low   Clear       4.27          NaN             0.34
# 29             Medium   Clear       3.62         1.51             0.49
# 30                Low   Clear       3.40         1.92             0.15
# 31               High    Rain       4.63         0.90             0.25
# 32               High   Clear       2.41         0.97             0.26
# 33                Low   Clear       2.17         0.89             0.27
# 34             Medium     NaN       3.68          NaN             0.19
# 35                Low   Clear       3.17         1.14             0.31
# 36             Medium   Clear       4.60         1.49             0.35
# 37             Medium   Clear       2.05         1.86              NaN
# 38                Low   Clear       2.36         0.88             0.13
# 39                Low   Clear       4.90         1.92             0.13
# 40                Low    Rain       3.38         1.48             0.29
# 41                Low   Clear        NaN         1.45             0.27
# 42                Low    Rain       3.69         1.14             0.14
# 43             Medium    Rain       4.25         1.72             0.48
# 44                Low   Clear       2.14         1.14             0.28
# 45                Low     NaN       4.97         0.79             0.33
# 46             Medium    Rain        NaN         0.84             0.11
# 47             Medium   Clear       3.55         1.50             0.13
# 48             Medium    Rain       2.90         1.10             0.15
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   40.57         NaN
# 1                  110.33         NaN
# 2                   79.94         NaN
# 3                   69.06         NaN
# 4                   90.14         NaN
# 5                  105.91         NaN
# 6                   62.79         NaN
# 7                   25.41         NaN
# 8                     NaN         NaN
# 9                   66.38         NaN
# 10                  62.87         NaN
# 11                  81.37         NaN
# 12                 107.25         NaN
# 13                  45.94         NaN
# 14                  82.21         NaN
# 15                    NaN         NaN
# 16                 108.34         NaN
# 17                  23.91         NaN
# 18                 113.99         NaN
# 19                  19.53         NaN
# 20                  59.25         NaN
# 21                  50.02         NaN
# 22                  71.54         NaN
# 23                  77.30         NaN
# 24                  73.27         NaN
# 25                  71.35         NaN
# 26                    NaN         NaN
# 27                  50.19         NaN
# 28                  90.81         NaN
# 29                  64.89         NaN
# 30                  51.56         NaN
# 31                  63.82         NaN
# 32                  80.84         NaN
# 33                  36.16         NaN
# 34                  31.66         NaN
# 35                  89.73         NaN
# 36                  62.07         NaN
# 37                  39.98         NaN
# 38                  57.18         NaN
# 39                  51.47         NaN
# 40                  40.72         NaN
# 41                  27.05         NaN
# 42                    NaN         NaN
# 43                  32.07         NaN
# 44                  23.10         NaN
# 45                 111.30         NaN
# 46                  31.43         NaN
# 47                 117.57         NaN
# 48                   9.99         NaN
